# %%
# %run "/home/jovyan/work/workspace/functions/create_spark_session.ipynb"

# %%
# %run "/home/jovyan/work/workspace/functions/paths.ipynb"

# %%
# %run "/home/jovyan/work/workspace/functions/dates.ipynb"

# %%
df = spark.read.format('delta').load(f'{bronze}sales')

# %%
df.toPandas()
# Out:
#              DATE  ce_brand_flvr    BRAND_NM Btlr_Org_LVL_C_Desc  \
# 0      2006-01-01           3440       LEMON              CANADA
# 1      2006-01-01           3440       LEMON           NORTHEAST
# 2      2006-01-01           3554  STRAWBERRY           SOUTHEAST
# 3      2006-01-01           3441   RASPBERRY             MIDWEST
# 4      2006-01-01           3440       LEMON                WEST
# ...           ...            ...         ...                 ...
# 16146  2006-03-29           3554  STRAWBERRY           NORTHEAST
# 16147  2006-03-29           3440       LEMON           SOUTHWEST
# 16148  2006-03-29           3440       LEMON           SOUTHEAST
# 16149  2006-03-29           3440       LEMON           SOUTHEAST
# 16150  2006-03-29           3554  STRAWBERRY                WEST
#
#               CHNL_GROUP           TRADE_CHNL_DESC PKG_CAT Pkg_Cat_Desc  \
# 0                LEISURE               SPORT VENUE    N20O    20Z/600ML
# 1                 SUPERS                 SUPERETTE    N20O    20Z/600ML
# 2              WORKPLACE            PLANT / OFFICE    N20O    20Z/600ML
# 3      MASS MERCHANDISER         MASS MERCHANDISER    N20O    20Z/600ML
# 4      MASS MERCHANDISER         MASS MERCHANDISER    N20O    20Z/600ML
# ...                  ...                       ...     ...          ...
# 16146          EDUCATION  PRIMARY/SECONDARY SCHOOL    N20O    20Z/600ML
# 16147            LEISURE               SPORT VENUE    N56P     500ML 6P
# 16148        RETAIL COLD    RETAIL SPECIALITY SVCS    N20O    20Z/600ML
# 16149             SUPERS        HYPER-MERCHANDISER    N56P     500ML 6P
# 16150        DRUG STORES                DRUG STORE    N20O    20Z/600ML
#
#          TSR_PCKG_NM   volume  YEAR  MONTH  PERIOD     dtcarga
# 0      .591L NRP 24L    22.48  2006      1       1  2026-02-14
# 1        20Z NRP 24L   100.00  2006      1       1  2026-02-14
# 2        20Z NRP 24L    66.14  2006      1       1  2026-02-14
# 3        20Z NRP 24L   222.50  2006      1       1  2026-02-14
# 4        20Z NRP 24L   302.50  2006      1       1  2026-02-14
# ...              ...      ...   ...    ...     ...         ...
# 16146    20Z NRP 24L  2302.50  2006      3       5  2026-02-14
# 16147     .5L NRP 6P     2.11  2006      3       5  2026-02-14
# 16148  20z NRP 24L S   353.85  2006      3       5  2026-02-14
# 16149     .5L NRP 6P  3911.97  2006      3       5  2026-02-14
# 16150    20Z NRP 24L   122.50  2006      3       5  2026-02-14
#
# [16151 rows x 14 columns]
