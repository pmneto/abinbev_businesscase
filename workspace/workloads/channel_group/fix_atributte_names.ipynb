# %%
# %run "/home/jovyan/work/workspace/functions/paths.ipynb"

# %%
workdir
# Out:
# '/home/jovyan/work'

# %%
# !ls -a /home/jovyan/work/lake
# Out:
# .  ..  bronze  gold  .ipynb_checkpoints  landing  silver

# %%
# !rm -rf /home/jovyan/work/lake/bronze

# %%
# !rm -rf /home/jovyan/work/lake/silver

# %%
# !rm -rf /home/jovyan/work/lake/gold
