# %%
from pyspark.sql import SparkSession

# 1. Tenta recuperar uma sessão que já esteja aberta (evita o erro de concorrência do Hive)
spark = SparkSession.getActiveSession()

if spark is None:
    spark = SparkSession.builder \
        .appName("ABI_Martech_MVP") \
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
        .config("spark.sql.catalogImplementation", "hive") \
        .config("spark.sql.warehouse.dir", "/home/jovyan/work/data/gold") \
        .enableHiveSupport() \
        .getOrCreate()
else:
    
   pass 

print(f"Spark Version: {spark.version}")
print(f"Catalog Implementation: {spark.conf.get('spark.sql.catalogImplementation')}")
# Out:
# Spark Version: 3.5.0
