# %%
from datetime import datetime, timezone, timedelta
from zoneinfo import ZoneInfo # Python 3.9+


utc = datetime.now(timezone.utc)
dtcarga = datetime.now(ZoneInfo("America/Sao_Paulo"))
# Out:
# 2026-02-13 05:54:56.991649+05:30
